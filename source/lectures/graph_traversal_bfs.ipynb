# %% [markdown]
# # Graph Traversal:  Breadth First Search

# %% [markdown]
# ## Motivation

# %% [markdown]
# * Google Robot

# %% [markdown]
# * Lewis Carroll's [Doublets](https://books.google.com/books?id=JkQCAAAAQAAJ&dq=charles%20dodgson&pg=PP1#v=onepage&q&f=false) (Knuth does it better then you)

# %% [markdown]
# * Rubic's Cube

# %% [markdown]
# * find diameter (G-d's Number)

# %% [markdown]
# * find a shortest path

# %% [markdown]
# ## Definition

# %% [markdown]
# Given a graph G, and a starting vertex s, a breadth first search, finds all vertices a distance of d from s, prior to moving to a distance of d+1.  It finds all children, prior to looking for grandchildren.

# %% [markdown]
# ## Attributes

# %% [markdown]
# * {distance | level}

# %% [markdown]
# * parent

# %% [markdown]
# * frontier

# %% [markdown]
# * {color | is_visited}

# %% [markdown]
# ## Operations

# %% [markdown]
# * traverse(G, s)
